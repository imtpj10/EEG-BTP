# %%
from biosppy import storage
from biosppy.signals import ecg
import pandas as pd
import csv

# load raw ECG signal
# #df = pd.read_csv('../Untitled Folder/musicDataAllSubjects.csv')
# file = open("aa.txt", "w")
# #Open CSV file to read CSV, note: reading and write file should be under "with"
# with open('../musicDataAllSubjects.csv') as csvFile:
#     #Read CSV
#     readCsv = csv.reader(csvFile)
#     for row in readCsv:
#         #Get Values and manupilate in the file.write
#         #id= row[0]
#         fp1 = row[2]
#         fp2=row[3]
        
#         #Write CSV you need format it to string if the value is an int
#         file.write(str(fp1)+" "+str(fp2)+"\n")
# #You Must Close the FIle after writing it.
# file.close()

# %%
import numpy as np
df = pd.read_csv('../new1.csv')[['fp1','fp2']]

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt
signal=df.to_numpy()
#plt.figure(figsize =(15, 10)) 
out = eeg.eeg(signal=signal, sampling_rate=500, show=True)
